# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import re
from collections import Counter
from collections import defaultdict
import matplotlib.pyplot as plt
from scipy.spatial import distance
import seaborn as sns
from wordcloud import WordCloud
import matplotlib.cm as cm

# %%
#to be changed accordingly, depending on data location in cloud or in local machine
#path = '/home/adhikari/Downloads/tbip/data'
output = 'output300000'

# %%
#Creating < >_10_bigrams.csv

#define an empty dataframe
df1 = pd.DataFrame()
for sess in range(97, 115):
    ideals = np.load(os.path.join(data_dir, str(sess), output, 'ideal_point_mean.npy'))
    vocab = pd.read_csv(os.path.join(data_dir, str(sess) , 'input','vocabulary.txt'), header = None)
    #To be uncommented accordingly
    #for neutral_10_bigrams.csv
    beta = np.load(os.path.join(data_dir, str(sess), output, 'neutral_topic_mean.npy')) #neutral
    #for negative_10_bigrams.csv
    #beta = np.load(os.path.join(data_dir, str(sess), output, 'negative_topic_mean.npy')) #negative
    #for positve_10_bigrams.csv
    #beta = np.load(os.path.join(data_dir, str(sess), output, 'positive_topic_mean.npy')) #positive
    beta = np.exp(beta) #model uses exp() values only
    t_quantile = np.quantile(ideals, 0.1) #10th quantile ideal point
    n_quantile = np.quantile(ideals, 0.9) #90th quantile ideal point
    for topic in range(0, 25):
        intensity = t_quantile * beta
        word_index = intensity[topic].argsort()[:10][::-1].tolist() # n top words to include in wordcloud

        weights = []
        for i in word_index:
            weights.append(beta[topic][i])
                
        weights = np.exp(weights)
        weights = weights/np.sum(weights)
        words_n = []
        for i in word_index:
            words_n.append(vocab[0][i])
        dictionary = pd.Series(weights, index = words_n).to_dict()
        words_n.reverse()
        weights = np.flip(weights)
        df = pd.DataFrame()
        df['session'] = [sess] * 10
        df['topic'] = [topic + 1] * 10
        df['bigram'] = words_n
        df['weight'] = weights
        df1 = pd.concat([df1, df], axis=0)
        print("Session ", sess, " Topic ", topic+1, " done!")
#uncomment accordingly
df1.to_csv(os.path.join(path, 'neutral_10_bigrams.csv'), index=True) #neutral
#df1.to_csv(os.path.join(path, 'negative_10_bigrams.csv'), index=True) #negative
#df1.to_csv(os.path.join(path, 'positive_10_bigrams.csv'), index=True) #positive
print("Saved!")
# Out:
# Session  97  Topic  1  done!
# Session  97  Topic  2  done!
# Session  97  Topic  3  done!
# Session  97  Topic  4  done!
# Session  97  Topic  5  done!
# Session  97  Topic  6  done!
# Session  97  Topic  7  done!
# Session  97  Topic  8  done!
# Session  97  Topic  9  done!
# Session  97  Topic  10  done!
# Session  97  Topic  11  done!
# Session  97  Topic  12  done!
# Session  97  Topic  13  done!
# Session  97  Topic  14  done!
# Session  97  Topic  15  done!
# Session  97  Topic  16  done!
# Session  97  Topic  17  done!
# Session  97  Topic  18  done!
# Session  97  Topic  19  done!
# Session  97  Topic  20  done!
# Session  97  Topic  21  done!
# Session  97  Topic  22  done!
# Session  97  Topic  23  done!
# Session  97  Topic  24  done!
# Session  97  Topic  25  done!
# Session  98  Topic  1  done!
# Session  98  Topic  2  done!
# Session  98  Topic  3  done!
# Session  98  Topic  4  done!
# Session  98  Topic  5  done!
# Session  98  Topic  6  done!
# Session  98  Topic  7  done!
# Session  98  Topic  8  done!
# Session  98  Topic  9  done!
# Session  98  Topic  10  done!
# Session  98  Topic  11  done!
# Session  98  Topic  12  done!
# Session  98  Topic  13  done!
# Session  98  Topic  14  done!
# Session  98  Topic  15  done!
# Session  98  Topic  16  done!
# Session  98  Topic  17  done!
# Session  98  Topic  18  done!
# Session  98  Topic  19  done!
# Session  98  Topic  20  done!
# Session  98  Topic  21  done!
# Session  98  Topic  22  done!
# Session  98  Topic  23  done!
# Session  98  Topic  24  done!
# Session  98  Topic  25  done!
# Session  99  Topic  1  done!
# Session  99  Topic  2  done!
# Session  99  Topic  3  done!
# Session  99  Topic  4  done!
# Session  99  Topic  5  done!
# Session  99  Topic  6  done!
# Session  99  Topic  7  done!
# Session  99  Topic  8  done!
# Session  99  Topic  9  done!
# Session  99  Topic  10  done!
# Session  99  Topic  11  done!
# Session  99  Topic  12  done!
# Session  99  Topic  13  done!
# Session  99  Topic  14  done!
# Session  99  Topic  15  done!
# Session  99  Topic  16  done!
# Session  99  Topic  17  done!
# Session  99  Topic  18  done!
# Session  99  Topic  19  done!
# Session  99  Topic  20  done!
# Session  99  Topic  21  done!
# Session  99  Topic  22  done!
# Session  99  Topic  23  done!
# Session  99  Topic  24  done!
# Session  99  Topic  25  done!
# Session  100  Topic  1  done!
# Session  100  Topic  2  done!
# Session  100  Topic  3  done!
# Session  100  Topic  4  done!
# Session  100  Topic  5  done!
# Session  100  Topic  6  done!
# Session  100  Topic  7  done!
# Session  100  Topic  8  done!
# Session  100  Topic  9  done!
# Session  100  Topic  10  done!
# Session  100  Topic  11  done!
# Session  100  Topic  12  done!
# Session  100  Topic  13  done!
# Session  100  Topic  14  done!
# Session  100  Topic  15  done!
# Session  100  Topic  16  done!
# Session  100  Topic  17  done!
# Session  100  Topic  18  done!
# Session  100  Topic  19  done!
# Session  100  Topic  20  done!
# Session  100  Topic  21  done!
# Session  100  Topic  22  done!
# Session  100  Topic  23  done!
# Session  100  Topic  24  done!
# Session  100  Topic  25  done!
# Session  101  Topic  1  done!
# Session  101  Topic  2  done!
# Session  101  Topic  3  done!
# Session  101  Topic  4  done!
# Session  101  Topic  5  done!
# Session  101  Topic  6  done!
# Session  101  Topic  7  done!
# Session  101  Topic  8  done!
# Session  101  Topic  9  done!
# Session  101  Topic  10  done!
# Session  101  Topic  11  done!
# Session  101  Topic  12  done!
# Session  101  Topic  13  done!
# Session  101  Topic  14  done!
# Session  101  Topic  15  done!
# Session  101  Topic  16  done!
# Session  101  Topic  17  done!
# Session  101  Topic  18  done!
# Session  101  Topic  19  done!
# Session  101  Topic  20  done!
# Session  101  Topic  21  done!
# Session  101  Topic  22  done!
# Session  101  Topic  23  done!
# Session  101  Topic  24  done!
# Session  101  Topic  25  done!
# Session  102  Topic  1  done!
# Session  102  Topic  2  done!
# Session  102  Topic  3  done!
# Session  102  Topic  4  done!
# Session  102  Topic  5  done!
# Session  102  Topic  6  done!
# Session  102  Topic  7  done!
# Session  102  Topic  8  done!
# Session  102  Topic  9  done!
# Session  102  Topic  10  done!
# Session  102  Topic  11  done!
# Session  102  Topic  12  done!
# Session  102  Topic  13  done!
# Session  102  Topic  14  done!
# Session  102  Topic  15  done!
# Session  102  Topic  16  done!
# Session  102  Topic  17  done!
# Session  102  Topic  18  done!
# Session  102  Topic  19  done!
# Session  102  Topic  20  done!
# Session  102  Topic  21  done!
# Session  102  Topic  22  done!
# Session  102  Topic  23  done!
# Session  102  Topic  24  done!
# Session  102  Topic  25  done!
# Session  103  Topic  1  done!
# Session  103  Topic  2  done!
# Session  103  Topic  3  done!
# Session  103  Topic  4  done!
# Session  103  Topic  5  done!
# Session  103  Topic  6  done!
# Session  103  Topic  7  done!
# Session  103  Topic  8  done!
# Session  103  Topic  9  done!
# Session  103  Topic  10  done!
# Session  103  Topic  11  done!
# Session  103  Topic  12  done!
# Session  103  Topic  13  done!
# Session  103  Topic  14  done!
# Session  103  Topic  15  done!
# Session  103  Topic  16  done!
# Session  103  Topic  17  done!
# Session  103  Topic  18  done!
# Session  103  Topic  19  done!
# Session  103  Topic  20  done!
# Session  103  Topic  21  done!
# Session  103  Topic  22  done!
# Session  103  Topic  23  done!
# Session  103  Topic  24  done!
# Session  103  Topic  25  done!
# Session  104  Topic  1  done!
# Session  104  Topic  2  done!
# Session  104  Topic  3  done!
# Session  104  Topic  4  done!
# Session  104  Topic  5  done!
# Session  104  Topic  6  done!
# Session  104  Topic  7  done!
# Session  104  Topic  8  done!
# Session  104  Topic  9  done!
# Session  104  Topic  10  done!
# Session  104  Topic  11  done!
# Session  104  Topic  12  done!
# Session  104  Topic  13  done!
# Session  104  Topic  14  done!
# Session  104  Topic  15  done!
# Session  104  Topic  16  done!
# Session  104  Topic  17  done!
# Session  104  Topic  18  done!
# Session  104  Topic  19  done!
# Session  104  Topic  20  done!
# Session  104  Topic  21  done!
# Session  104  Topic  22  done!
# Session  104  Topic  23  done!
# Session  104  Topic  24  done!
# Session  104  Topic  25  done!
# Session  105  Topic  1  done!
# Session  105  Topic  2  done!
# Session  105  Topic  3  done!
# Session  105  Topic  4  done!
# Session  105  Topic  5  done!
# Session  105  Topic  6  done!
# Session  105  Topic  7  done!
# Session  105  Topic  8  done!
# Session  105  Topic  9  done!
# Session  105  Topic  10  done!
# Session  105  Topic  11  done!
# Session  105  Topic  12  done!
# Session  105  Topic  13  done!
# Session  105  Topic  14  done!
# Session  105  Topic  15  done!
# Session  105  Topic  16  done!
# Session  105  Topic  17  done!
# Session  105  Topic  18  done!
# Session  105  Topic  19  done!
# Session  105  Topic  20  done!
# Session  105  Topic  21  done!
# Session  105  Topic  22  done!
# Session  105  Topic  23  done!
# Session  105  Topic  24  done!
# Session  105  Topic  25  done!
# Session  106  Topic  1  done!
# Session  106  Topic  2  done!
# Session  106  Topic  3  done!
# Session  106  Topic  4  done!
# Session  106  Topic  5  done!
# Session  106  Topic  6  done!
# Session  106  Topic  7  done!
# Session  106  Topic  8  done!
# Session  106  Topic  9  done!
# Session  106  Topic  10  done!
# Session  106  Topic  11  done!
# Session  106  Topic  12  done!
# Session  106  Topic  13  done!
# Session  106  Topic  14  done!
# Session  106  Topic  15  done!
# Session  106  Topic  16  done!
# Session  106  Topic  17  done!
# Session  106  Topic  18  done!
# Session  106  Topic  19  done!
# Session  106  Topic  20  done!
# Session  106  Topic  21  done!
# Session  106  Topic  22  done!
# Session  106  Topic  23  done!
# Session  106  Topic  24  done!
# Session  106  Topic  25  done!
# Session  107  Topic  1  done!
# Session  107  Topic  2  done!
# Session  107  Topic  3  done!
# Session  107  Topic  4  done!
# Session  107  Topic  5  done!
# Session  107  Topic  6  done!
# Session  107  Topic  7  done!
# Session  107  Topic  8  done!
# Session  107  Topic  9  done!
# Session  107  Topic  10  done!
# Session  107  Topic  11  done!
# Session  107  Topic  12  done!
# Session  107  Topic  13  done!
# Session  107  Topic  14  done!
# Session  107  Topic  15  done!
# Session  107  Topic  16  done!
# Session  107  Topic  17  done!
# Session  107  Topic  18  done!
# Session  107  Topic  19  done!
# Session  107  Topic  20  done!
# Session  107  Topic  21  done!
# Session  107  Topic  22  done!
# Session  107  Topic  23  done!
# Session  107  Topic  24  done!
# Session  107  Topic  25  done!
# Session  108  Topic  1  done!
# Session  108  Topic  2  done!
# Session  108  Topic  3  done!
# Session  108  Topic  4  done!
# Session  108  Topic  5  done!
# Session  108  Topic  6  done!
# Session  108  Topic  7  done!
# Session  108  Topic  8  done!
# Session  108  Topic  9  done!
# Session  108  Topic  10  done!
# Session  108  Topic  11  done!
# Session  108  Topic  12  done!
# Session  108  Topic  13  done!
# Session  108  Topic  14  done!
# Session  108  Topic  15  done!
# Session  108  Topic  16  done!
# Session  108  Topic  17  done!
# Session  108  Topic  18  done!
# Session  108  Topic  19  done!
# Session  108  Topic  20  done!
# Session  108  Topic  21  done!
# Session  108  Topic  22  done!
# Session  108  Topic  23  done!
# Session  108  Topic  24  done!
# Session  108  Topic  25  done!
# Session  109  Topic  1  done!
# Session  109  Topic  2  done!
# Session  109  Topic  3  done!
# Session  109  Topic  4  done!
# Session  109  Topic  5  done!
# Session  109  Topic  6  done!
# Session  109  Topic  7  done!
# Session  109  Topic  8  done!
# Session  109  Topic  9  done!
# Session  109  Topic  10  done!
# Session  109  Topic  11  done!
# Session  109  Topic  12  done!
# Session  109  Topic  13  done!
# Session  109  Topic  14  done!
# Session  109  Topic  15  done!
# Session  109  Topic  16  done!
# Session  109  Topic  17  done!
# Session  109  Topic  18  done!
# Session  109  Topic  19  done!
# Session  109  Topic  20  done!
# Session  109  Topic  21  done!
# Session  109  Topic  22  done!
# Session  109  Topic  23  done!
# Session  109  Topic  24  done!
# Session  109  Topic  25  done!
# Session  110  Topic  1  done!
# Session  110  Topic  2  done!
# Session  110  Topic  3  done!
# Session  110  Topic  4  done!
# Session  110  Topic  5  done!
# Session  110  Topic  6  done!
# Session  110  Topic  7  done!
# Session  110  Topic  8  done!
# Session  110  Topic  9  done!
# Session  110  Topic  10  done!
# Session  110  Topic  11  done!
# Session  110  Topic  12  done!
# Session  110  Topic  13  done!
# Session  110  Topic  14  done!
# Session  110  Topic  15  done!
# Session  110  Topic  16  done!
# Session  110  Topic  17  done!
# Session  110  Topic  18  done!
# Session  110  Topic  19  done!
# Session  110  Topic  20  done!
# Session  110  Topic  21  done!
# Session  110  Topic  22  done!
# Session  110  Topic  23  done!
# Session  110  Topic  24  done!
# Session  110  Topic  25  done!
# Session  111  Topic  1  done!
# Session  111  Topic  2  done!
# Session  111  Topic  3  done!
# Session  111  Topic  4  done!
# Session  111  Topic  5  done!
# Session  111  Topic  6  done!
# Session  111  Topic  7  done!
# Session  111  Topic  8  done!
# Session  111  Topic  9  done!
# Session  111  Topic  10  done!
# Session  111  Topic  11  done!
# Session  111  Topic  12  done!
# Session  111  Topic  13  done!
# Session  111  Topic  14  done!
# Session  111  Topic  15  done!
# Session  111  Topic  16  done!
# Session  111  Topic  17  done!
# Session  111  Topic  18  done!
# Session  111  Topic  19  done!
# Session  111  Topic  20  done!
# Session  111  Topic  21  done!
# Session  111  Topic  22  done!
# Session  111  Topic  23  done!
# Session  111  Topic  24  done!
# Session  111  Topic  25  done!
# Session  112  Topic  1  done!
# Session  112  Topic  2  done!
# Session  112  Topic  3  done!
# Session  112  Topic  4  done!
# Session  112  Topic  5  done!
# Session  112  Topic  6  done!
# Session  112  Topic  7  done!
# Session  112  Topic  8  done!
# Session  112  Topic  9  done!
# Session  112  Topic  10  done!
# Session  112  Topic  11  done!
# Session  112  Topic  12  done!
# Session  112  Topic  13  done!
# Session  112  Topic  14  done!
# Session  112  Topic  15  done!
# Session  112  Topic  16  done!
# Session  112  Topic  17  done!
# Session  112  Topic  18  done!
# Session  112  Topic  19  done!
# Session  112  Topic  20  done!
# Session  112  Topic  21  done!
# Session  112  Topic  22  done!
# Session  112  Topic  23  done!
# Session  112  Topic  24  done!
# Session  112  Topic  25  done!
# Session  113  Topic  1  done!
# Session  113  Topic  2  done!
# Session  113  Topic  3  done!
# Session  113  Topic  4  done!
# Session  113  Topic  5  done!
# Session  113  Topic  6  done!
# Session  113  Topic  7  done!
# Session  113  Topic  8  done!
# Session  113  Topic  9  done!
# Session  113  Topic  10  done!
# Session  113  Topic  11  done!
# Session  113  Topic  12  done!
# Session  113  Topic  13  done!
# Session  113  Topic  14  done!
# Session  113  Topic  15  done!
# Session  113  Topic  16  done!
# Session  113  Topic  17  done!
# Session  113  Topic  18  done!
# Session  113  Topic  19  done!
# Session  113  Topic  20  done!
# Session  113  Topic  21  done!
# Session  113  Topic  22  done!
# Session  113  Topic  23  done!
# Session  113  Topic  24  done!
# Session  113  Topic  25  done!
# Session  114  Topic  1  done!
# Session  114  Topic  2  done!
# Session  114  Topic  3  done!
# Session  114  Topic  4  done!
# Session  114  Topic  5  done!
# Session  114  Topic  6  done!
# Session  114  Topic  7  done!
# Session  114  Topic  8  done!
# Session  114  Topic  9  done!
# Session  114  Topic  10  done!
# Session  114  Topic  11  done!
# Session  114  Topic  12  done!
# Session  114  Topic  13  done!
# Session  114  Topic  14  done!
# Session  114  Topic  15  done!
# Session  114  Topic  16  done!
# Session  114  Topic  17  done!
# Session  114  Topic  18  done!
# Session  114  Topic  19  done!
# Session  114  Topic  20  done!
# Session  114  Topic  21  done!
# Session  114  Topic  22  done!
# Session  114  Topic  23  done!
# Session  114  Topic  24  done!
# Session  114  Topic  25  done!
# Saved!

# %%
#print(df1)
